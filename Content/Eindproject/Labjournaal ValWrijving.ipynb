# %% [markdown]
# # General
# Template for labjournaal. See https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html for options to use markdown.
#
# **Name:**  Lukas Calixtro & Oskar van Velze
# **Title of the experiment:**  Een benadering van het verband tussen valsnelheid en weerstandscoëfficiënt van vallende
# waterdruppels
# **Starting date:**  09/01/26
# **Expected enddate:**  23/01/26
# **Goal of the experiment:**  Bepalen hoe de valsnelheid en de weerstandscoëfficiënt van een vallend voorwerp elkaar beïnvloeden
# **Research question:**  Wat is het verband tussen de valsnelheid en de weerstandcoëfficiënt van een vallend waterdruppel
# **Expectations or Hypothesis:**  Hoe groter de valsnelheid wordt hoe meer de weerstandscoëfficiënt ook zal toenemen
# **Desired accuracy:**  >50%

# %%
#import necessary libraries
import matplotlib.pyplot as plt
import numpy as np
import math
from scipy.optimize import curve_fit

# %% [markdown]
# # Preparation

# %% [markdown]
# **Assignments:**

# %% [markdown]
# Op elk voorwerp dat door een vloeistof of gas heen beweegt, werkt een wrijvingskracht .
# (𝐹
# 𝐷)
# Voor vallende voorwerpen geldt dat de wrijvingskracht afhangt van een bepaalde drag
# coefficient , in het Nederlands wrijvingscoëfficiënt. Deze wrijvingscoëfficiënt is afhankelijk
# (𝐶
# 𝐷)
# van eigenschappen van zowel het vallend voorwerp als het medium waardoor het valt en de
# snelheid van het vallend voorwerp. Het doel van dit onderzoek is het verband tussen de
# wrijvingscoëfficiënt en de snelheid van een vallende waterdruppel door lucht te bepalen. Een
# waterdruppel wordt afzonderlijk uit een pipet gedruppeld vanaf verschillende hoogtes. De
# waterdruppels vallen door de lucht en er wordt aangenomen dat alle waterdruppels identiek
# zijn aan elkaar. De valtijd van deze hoogtes wordt samengenomen met de valtijd om de
# wrijvingscoëfficiënt en de maximale bereikte snelheid van de waterdruppels te berekenen. Deze
# twee gevonden waarden worden in python tegenover elkaar geplot om het verband tussen de
# twee gevonden waardes te zien. Op basis van de bewegingsvergelijkingen van vallende
# voorwerpen en de vergelijking voor de wrijvingscoëfficiënt, wordt verwacht dat zij een
# omgekeerd evenredig verband hebben. Dus, naarmate de maximale bereikte snelheid van de
# vallende waterdruppels toeneemt zal de wrijvingscoëfficiënt van de vallende waterdruppels
# afnemen.
#
# **Method:**
# **Theory:**
# **Independent variable:**
# 1. Valhoogte
#
# **Dependent variable:**
# 1. Valtijd
#
# **Controlled variablen:**
# 1. Vorm en grootte van druppel
# 2. Valversnelling
#
# In dit experiment wordt geprobeerd om de relatie tussen de wrijvingscoëfficiënt en de snelheid
# van een vallende waterdruppel aan te tonen. Dit wordt gedaan door gebruik
# te maken van de standaard opstelling die getoond wordt in beide figuur 14.8
# van de handleiding en hier rechts. Waarbij de bovenste detector wordt
# geplaatst net onder de pipet, met markeringen v0=s0=t0=0 en de detector
# onder, net boven de grond. Om voor verschillende snelheden de
# weerstandscoëfficiënt te bepalen wordt de valhoogte gevarieerd. Omdat met
# een grotere valhoogte de waterdruppels een hogere valsnelheid bereiken.
# Vervolgens zal voor iedere ingestelde valhoogte een serie van 10 metingen
# gedaan worden aan de valtijd, dit om enige willekeurige onzekerheid teniet
# te doen. De gemiddelde waarde voor valtijd die uit deze serie metingen komt
# wordt vervolgens gebruikt om met vergelijking 14.9 uit de handleiding,
# omgeschreven voor de weerstandscoëfficiënt, CD te bepalen. Vervolgens
# wordt met vergelijking 14.7 uit de handleiding, waarbij de termen vanaf de
# tweede correctie verwaarloosd worden door de kleine valtijd, de maximale
# snelheid die de waterdruppels behalen bepaald.
#
# **Measurement instruments \& Settings:**
# **Procedure:**
# **Setup(drawing or picture):**
# **Notes:**
# **About accuracy:**

# %% [markdown]
# # Execution

# %%
rho_water = 998.2     #Dichtheid van water (kg.m^-3)
rho_lucht = 1.225     #Dichtheid van lucht (kg.m^-3)
g = 9.81            #Valversnelling (m/s^-2)

# %%
#Raw Data
Data = np.loadtxt('Raw_ValWrijving.csv',delimiter=';', skiprows=1)      #Data importeren

# %% [markdown]
# **Observations:**
# - Een grotere valhoogte zorgde voor een een steeds langere valtijd, wat logisch is
# - Tijden het meten, miste de druppel soms de tweede sensor
# - Wanneer een druppel op een verschillend manier uit het pipet gedruppeld, ontstond een klein verschil in de valtijd. Hierom werd er voor gezorgd dat ieder druppel op dezelfde manier eruit gedruppeld
#
# **Notes:**

# %% [markdown]
# # Processing
# **Description of processing of raw data into scientific evidence:**

# %%
#Data processing and analysis:

Hoogte_Data = Data[:,0]    #Valhoogte (m)

#Alle 10 valtijd metingen per hoogte (s)
Val_Data1 = Data[0,1:]
Val_Data2 = Data[1,1:]
Val_Data3 = Data[2,1:]
Val_Data4 = Data[3,1:]
Val_Data5 = Data[4,1:]
Val_Data6 = Data[5,1:]
Val_Data7 = Data[6,1:]
Val_Data8 = Data[7,1:]
Val_Data9 = Data[8,1:]
Val_Data10 = Data[9,1:]
Val_Data11 = Data[10,1:]

#Gemiddelde valtijd per hoogte (s)
Val_tijd1 = np.mean(Val_Data1)
Val_tijd2 = np.mean(Val_Data2)
Val_tijd3 = np.mean(Val_Data3)
Val_tijd4 = np.mean(Val_Data4)
Val_tijd5 = np.mean(Val_Data5)
Val_tijd6 = np.mean(Val_Data6)
Val_tijd7 = np.mean(Val_Data7)
Val_tijd8 = np.mean(Val_Data8)
Val_tijd9 = np.mean(Val_Data9)
Val_tijd10 = np.mean(Val_Data10)
Val_tijd11 = np.mean(Val_Data11)

#Gemiddelde valsnelheid per hoogte(m/s)
Val_snelheid1 = Hoogte_Data[0]/Val_tijd1
Val_snelheid2 = Hoogte_Data[1]/Val_tijd2
Val_snelheid3 = Hoogte_Data[2]/Val_tijd3
Val_snelheid4 = Hoogte_Data[3]/Val_tijd4
Val_snelheid5 = Hoogte_Data[4]/Val_tijd5
Val_snelheid6 = Hoogte_Data[5]/Val_tijd6
Val_snelheid7 = Hoogte_Data[6]/Val_tijd7
Val_snelheid8 = Hoogte_Data[7]/Val_tijd8
Val_snelheid9 = Hoogte_Data[8]/Val_tijd9
Val_snelheid10 = Hoogte_Data[9]/Val_tijd10
Val_snelheid11 = Hoogte_Data[10]/Val_tijd10   

Val_tijden = np.array([Val_tijd1, Val_tijd2, Val_tijd3, Val_tijd4, Val_tijd5, Val_tijd6, Val_tijd7, Val_tijd8, Val_tijd9, Val_tijd10, Val_tijd11])
Val_snelheden = np.array([Val_snelheid1, Val_snelheid2, Val_snelheid3, Val_snelheid4, Val_snelheid5, Val_snelheid6, Val_snelheid7, Val_snelheid8, Val_snelheid9, Val_snelheid10, Val_snelheid11])

#Test plot
plt.figure()
plt.plot(Val_tijden, Hoogte_Data, 'r.')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Data processing and analysis:
L_naald = 0.0105 #Daadwerkelijke lengte van naald (m)

#Diameters zijn berekend met behulp van Fiji-software en schaal van L_naald
#Aangenomen dat alle druppels perfect bolvormig zijn, ook al zijn ze dat in de fotos niet helemaal
#Uit de fotos afgeleide diameters (m)
D_druppel1 = 0.003875 
D_druppel2 = 0.003993 
D_druppel3 = 0.003888

#Straal van druppels (m)
R_druppel1 = D_druppel1/2
R_druppel2 = D_druppel2/2
R_druppel3 = D_druppel3/2

#Volume van druppels (m^3)
#Aangenomen dat druppels perfect bolvormig zijn
V_druppel1 = (4/3)*np.pi*R_druppel1
V_druppel2 = (4/3)*np.pi*R_druppel2
V_druppel3 = (4/3)*np.pi*R_druppel3

#Massa van druppels (kg)
m_druppel1 = rho_water*V_druppel1
m_druppel2 = rho_water*V_druppel2
m_druppel3 = rho_water*V_druppel3

# %% [markdown]
# **Describing the pattern in the processed data:**

# %% [markdown]
# Integreren van Vgl. (14.7) geeft, onder verwaarlozing van de tweede orde correctie:
#
# (14.8)
#  $$
#     s(t) = s_0 + v_0t + \frac{1}{2}gt^2 - \frac{\beta g^2}{12m}t^4
#  $$
# waarin
#  de afgelegde weg is bij
# . Als we een situatie kunnen creëren waarin bij
#  zowel de beginpositie als de beginsnelheid nul zijn, dan volgt uit Vgl. (14.8):
#
# (14.9)
#  $$
#    s(t) - \frac{1}{2}gt^2 = -\frac{\beta g^2}{12m}t^4
# $$
#
#
# In woorden staat hier dat de valafstand in lucht op ieder moment is gereduceerd t.o.v. de valafstand bij een vrije val met een hoeveelheid die evenredig is met de valtijd tot de vierde macht. De evenredigheidsconstante bevat de parameter
# , die zelf weer evenredig is met
# . Aan de hand van deze vergelijking kan een experiment worden bedacht waarbij bijvoorbeeld
#  voor een vallende waterdruppel wordt bepaald. In Figuur 14.8 is een voorbeeld van een opstelling weergeven die hiervoor gebruikt kan worden (en bij het practicum aanwezig is).

# %%
#Calculations of e.a. measurement uncertainties, and providing final answers.
#Eventueel waardes van druppel gebruikt
def eom(beta,t):
    return ((0.5 * g * t**2) - (((beta * g**2) / (12 * m_druppel1)) * t**4))

popt, pcov = curve_fit(eom, Val_tijden, Hoogte_Data)
beta_fit = popt[0]
u_beta_fit = np.sqrt(np.diag(pcov))[0]

#Plot met fit
t_fit = np.linspace(min(Val_tijden), max(Val_tijden),100)
H_fit = eom(beta_fit, t_fit)

plt.figure()
plt.plot(Val_tijden, Hoogte_Data, 'r.', label='Data')
plt.plot(t_fit, H_fit, 'b--', label='Fit')
plt.xlabel('Valtijd (s)')
plt.ylabel('Valhoogte (m)')
plt.show()

# %%
print(H_fit[0])
# Out:
# 0.5105994144884826

# %% [markdown]
# **Notes:**

# %% [markdown]
# # Discussion

# %% [markdown]
# # Conclusion

# %% [markdown]
# # Additional notes, remarks, explanations, thoughts etc
